# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/Crime.csv')

# %%
df
# Out:
#            DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0      190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130
# 1      200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800
# 2      200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700
# 3      200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037
# 4      220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200
# ...          ...                     ...                     ...       ...
# 77687  201006265  02/20/2020 12:00:00 AM  02/20/2020 12:00:00 AM      1530
# 77688  200807552  03/21/2020 12:00:00 AM  03/07/2020 12:00:00 AM      1200
# 77689  201209936  03/28/2020 12:00:00 AM  03/28/2020 12:00:00 AM      1740
# 77690  201007352  03/18/2020 12:00:00 AM  03/11/2020 12:00:00 AM      1800
# 77691  201707086  03/07/2020 12:00:00 AM  03/07/2020 12:00:00 AM      1615
#
#        AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0         7     Wilshire          784         1     510
# 1         1      Central          182         1     330
# 2         3    Southwest          356         1     480
# 3         9     Van Nuys          964         1     343
# 4         6    Hollywood          666         2     354
# ...     ...          ...          ...       ...     ...
# 77687    10  West Valley         1023         2     624
# 77688     8      West LA          842         2     946
# 77689    12  77th Street         1203         1     230
# 77690    10  West Valley         1045         1     510
# 77691    17   Devonshire         1751         1     230
#
#                                           Crm Cd Desc  ... Status  \
# 0                                    VEHICLE - STOLEN  ...     AA
# 1                               BURGLARY FROM VEHICLE  ...     IC
# 2                                       BIKE - STOLEN  ...     IC
# 3            SHOPLIFTING-GRAND THEFT ($950.01 & OVER)  ...     IC
# 4                                   THEFT OF IDENTITY  ...     IC
# ...                                               ...  ...    ...
# 77687                        BATTERY - SIMPLE ASSAULT  ...     AO
# 77688                       OTHER MISCELLANEOUS CRIME  ...     IC
# 77689  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...     AA
# 77690                                VEHICLE - STOLEN  ...     IC
# 77691                                             NaN  ...    NaN
#
#         Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0      Adult Arrest    510.0    998.0       NaN      NaN
# 1       Invest Cont    330.0    998.0       NaN      NaN
# 2       Invest Cont    480.0      NaN       NaN      NaN
# 3       Invest Cont    343.0      NaN       NaN      NaN
# 4       Invest Cont    354.0      NaN       NaN      NaN
# ...             ...      ...      ...       ...      ...
# 77687   Adult Other    624.0      NaN       NaN      NaN
# 77688   Invest Cont    946.0      NaN       NaN      NaN
# 77689  Adult Arrest    230.0      NaN       NaN      NaN
# 77690   Invest Cont    510.0      NaN       NaN      NaN
# 77691           NaN      NaN      NaN       NaN      NaN
#
#                                        LOCATION  \
# 0       1900 S  LONGWOOD                     AV
# 1       1000 S  FLOWER                       ST
# 2       1400 W  37TH                         ST
# 3      14000    RIVERSIDE                    DR
# 4                             1900    TRANSIENT
# ...                                         ...
# 77687   7100    WILBUR                       AV
# 77688   1400 S  WESTGATE                     AV
# 77689           48TH                         ST
# 77690                                 WHITE OAK
# 77691                                       NaN
#
#                           Cross Street      LAT       LON
# 0                                  NaN  34.0375 -118.3506
# 1                                  NaN  34.0444 -118.2628
# 2                                  NaN  34.0210 -118.3002
# 3                                  NaN  34.1576 -118.4387
# 4                                  NaN  34.0944 -118.3277
# ...                                ...      ...       ...
# 77687                              NaN  34.1993 -118.5448
# 77688                              NaN  34.0444 -118.4610
# 77689  WESTERN                      AV  34.0001 -118.3089
# 77690                         HATTERAS  34.1767 -118.5185
# 77691                              NaN      NaN       NaN
#
# [77692 rows x 28 columns]

# %%
#Define each value counts

df.value_counts()
# Out:
# DR_NO      Date Rptd               DATE OCC                TIME OCC  AREA  AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  Crm Cd Desc      Mocodes                                       Vict Age  Vict Sex  Vict Descent  Premis Cd  Premis Desc  Weapon Used Cd  Weapon Desc                       Status  Status Desc   Crm Cd 1  Crm Cd 2  Crm Cd 3  Crm Cd 4  LOCATION                         Cross Street                     LAT      LON
# 201904032  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM  2135      19    Mission    1924         1         761     BRANDISH WEAPON  1822 3006 3028 3039 3032 3037 3101 4019 3602  41.0      M         H             101.0      STREET       200.0           KNIFE WITH BLADE 6INCHES OR LESS  AA      Adult Arrest  761.0     930.0     997.0     998.0     ASTORIA                      ST  SAN FERNANDO                 RD  34.2949  -118.4571    1
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# DR_NO               int64
# Date Rptd          object
# DATE OCC           object
# TIME OCC            int64
# AREA                int64
# AREA NAME          object
# Rpt Dist No         int64
# Part 1-2            int64
# Crm Cd              int64
# Crm Cd Desc        object
# Mocodes            object
# Vict Age          float64
# Vict Sex           object
# Vict Descent       object
# Premis Cd         float64
# Premis Desc        object
# Weapon Used Cd    float64
# Weapon Desc        object
# Status             object
# Status Desc        object
# Crm Cd 1          float64
# Crm Cd 2          float64
# Crm Cd 3          float64
# Crm Cd 4          float64
# LOCATION           object
# Cross Street       object
# LAT               float64
# LON               float64
# dtype: object

# %%
df.columns
# Out:
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
#        'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
#        'LON'],
#       dtype='object')

# %% [markdown]
# #**Uni-Variate Analysis**

# %%
df['AREA'].unique()
# Out:
# array([ 7,  1,  3,  9,  6, 18, 13, 19,  2, 10,  8, 20,  4, 21, 11, 12, 14,
#        15,  5, 16, 17])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77692 entries, 0 to 77691
# Data columns (total 28 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   DR_NO           77692 non-null  int64
#  1   Date Rptd       77692 non-null  object
#  2   DATE OCC        77692 non-null  object
#  3   TIME OCC        77692 non-null  int64
#  4   AREA            77692 non-null  int64
#  5   AREA NAME       77692 non-null  object
#  6   Rpt Dist No     77692 non-null  int64
#  7   Part 1-2        77692 non-null  int64
#  8   Crm Cd          77692 non-null  int64
#  9   Crm Cd Desc     77691 non-null  object
#  10  Mocodes         67316 non-null  object
#  11  Vict Age        77691 non-null  float64
#  12  Vict Sex        67826 non-null  object
#  13  Vict Descent    67824 non-null  object
#  14  Premis Cd       77689 non-null  float64
#  15  Premis Desc     77660 non-null  object
#  16  Weapon Used Cd  28280 non-null  float64
#  17  Weapon Desc     28280 non-null  object
#  18  Status          77691 non-null  object
#  19  Status Desc     77691 non-null  object
#  20  Crm Cd 1        77690 non-null  float64
#  21  Crm Cd 2        6317 non-null   float64
#  22  Crm Cd 3        217 non-null    float64
#  23  Crm Cd 4        10 non-null     float64
#  24  LOCATION        77691 non-null  object
#  25  Cross Street    13420 non-null  object
#  26  LAT             77691 non-null  float64
#  27  LON             77691 non-null  float64
# dtypes: float64(9), int64(6), object(13)
# memory usage: 16.6+ MB

# %%
df.shape #No.of rows and columns
# Out:
# (77692, 28)

# %%
df.isna().sum()/df.shape[0]  #calculates the percentage of missing values in each column of the DataFrame df.
# Out:
# DR_NO             0.000000
# Date Rptd         0.000000
# DATE OCC          0.000000
# TIME OCC          0.000000
# AREA              0.000000
# AREA NAME         0.000000
# Rpt Dist No       0.000000
# Part 1-2          0.000000
# Crm Cd            0.000000
# Crm Cd Desc       0.000013
# Mocodes           0.133553
# Vict Age          0.000013
# Vict Sex          0.126989
# Vict Descent      0.127014
# Premis Cd         0.000039
# Premis Desc       0.000412
# Weapon Used Cd    0.635999
# Weapon Desc       0.635999
# Status            0.000013
# Status Desc       0.000013
# Crm Cd 1          0.000026
# Crm Cd 2          0.918692
# Crm Cd 3          0.997207
# Crm Cd 4          0.999871
# LOCATION          0.000013
# Cross Street      0.827267
# LAT               0.000013
# LON               0.000013
# dtype: float64

# %%
(df.isna().sum()/df.shape[0]).sort_values()
# Out:
# DR_NO             0.000000
# Date Rptd         0.000000
# DATE OCC          0.000000
# TIME OCC          0.000000
# AREA              0.000000
# AREA NAME         0.000000
# Rpt Dist No       0.000000
# Part 1-2          0.000000
# Crm Cd            0.000000
# LOCATION          0.000013
# Status Desc       0.000013
# Status            0.000013
# LAT               0.000013
# LON               0.000013
# Vict Age          0.000013
# Crm Cd Desc       0.000013
# Crm Cd 1          0.000026
# Premis Cd         0.000039
# Premis Desc       0.000412
# Vict Sex          0.126989
# Vict Descent      0.127014
# Mocodes           0.133553
# Weapon Used Cd    0.635999
# Weapon Desc       0.635999
# Cross Street      0.827267
# Crm Cd 2          0.918692
# Crm Cd 3          0.997207
# Crm Cd 4          0.999871
# dtype: float64

# %%
(df.isna().sum()/df.shape[0]).sort_values().plot(kind="bar")
# Out:
# <Axes: >

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # **Summerization**

# %%
df.describe() # descriptive statistics for each numerical column in your DataFrame.
# Out:
#               DR_NO      TIME OCC          AREA   Rpt Dist No      Part 1-2  \
# count  7.769200e+04  77692.000000  77692.000000  77692.000000  77692.000000
# mean   2.019274e+08   1347.927985     10.831154   1129.014699      1.422746
# std    4.125875e+06    648.918183      6.017504    601.867826      0.493999
# min    8.170000e+02      1.000000      1.000000    101.000000      1.000000
# 25%    2.006107e+08    918.750000      6.000000    635.000000      1.000000
# 50%    2.012081e+08   1430.000000     11.000000   1151.000000      1.000000
# 75%    2.017092e+08   1900.000000     16.000000   1623.000000      2.000000
# max    2.420047e+08   2359.000000     21.000000   2198.000000      2.000000
#
#              Crm Cd      Vict Age     Premis Cd  Weapon Used Cd      Crm Cd 1  \
# count  77692.000000  77691.000000  77689.000000    28280.000000  77690.000000
# mean     508.490269     30.073162    298.604049      364.660113    508.178968
# std      209.665924     21.724008    212.759810      121.667966    209.417037
# min      110.000000     -3.000000    101.000000      101.000000    110.000000
# 25%      330.000000     12.000000    101.000000      311.000000    330.000000
# 50%      480.000000     31.000000    203.000000      400.000000    480.000000
# 75%      626.000000     46.000000    501.000000      400.000000    626.000000
# max      956.000000     99.000000    974.000000      516.000000    956.000000
#
#           Crm Cd 2    Crm Cd 3  Crm Cd 4           LAT           LON
# count  6317.000000  217.000000      10.0  77691.000000  77691.000000
# mean    949.632737  982.599078     998.0     33.941643   -117.897904
# std     121.062450   51.626692       0.0      2.116277      7.341211
# min     210.000000  626.000000     998.0      0.000000   -118.667600
# 25%     998.000000  998.000000     998.0     34.008900   -118.431200
# 50%     998.000000  998.000000     998.0     34.058100   -118.322600
# 75%     998.000000  998.000000     998.0     34.166000   -118.274500
# max     999.000000  998.000000     998.0     34.329300      0.000000

# %%
df.describe(include=['object','category'])
# Out:
#                      Date Rptd                DATE OCC    AREA NAME  \
# count                    77692                   77692        77692
# unique                    1301                     366           21
# top     07/13/2020 12:00:00 AM  01/01/2020 12:00:00 AM  77th Street
# freq                       276                     545         5169
#
#              Crm Cd Desc Mocodes Vict Sex Vict Descent Premis Desc  \
# count              77691   67316    67826        67824       77660
# unique               123   35448        4           19         269
# top     VEHICLE - STOLEN    0344        M            H      STREET
# freq                8054    3252    32917        23941       19496
#
#                                            Weapon Desc Status  Status Desc  \
# count                                            28280  77691        77691
# unique                                              72      5            5
# top     STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     IC  Invest Cont
# freq                                             15271  59259        59259
#
#        LOCATION Cross Street
# count     77691        13420
# unique    28207         3370
# top         7TH     BROADWAY
# freq        141          223

# %% [markdown]
# **Histograms**

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'DR_NO'}>,
#         <Axes: title={'center': 'TIME OCC'}>,
#         <Axes: title={'center': 'AREA'}>,
#         <Axes: title={'center': 'Rpt Dist No'}>],
#        [<Axes: title={'center': 'Part 1-2'}>,
#         <Axes: title={'center': 'Crm Cd'}>,
#         <Axes: title={'center': 'Vict Age'}>,
#         <Axes: title={'center': 'Premis Cd'}>],
#        [<Axes: title={'center': 'Weapon Used Cd'}>,
#         <Axes: title={'center': 'Crm Cd 1'}>,
#         <Axes: title={'center': 'Crm Cd 2'}>,
#         <Axes: title={'center': 'Crm Cd 3'}>],
#        [<Axes: title={'center': 'Crm Cd 4'}>,
#         <Axes: title={'center': 'LAT'}>, <Axes: title={'center': 'LON'}>,
#         <Axes: >]], dtype=object)

# %%
df.iloc[:,0:4].hist()
# Out:
# array([[<Axes: title={'center': 'DR_NO'}>,
#         <Axes: title={'center': 'TIME OCC'}>]], dtype=object)

# %%
df.iloc[:,0:4].hist(bins=20)
# Out:
# array([[<Axes: title={'center': 'DR_NO'}>,
#         <Axes: title={'center': 'TIME OCC'}>]], dtype=object)

# %%
df['AREA NAME'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='AREA NAME'>
